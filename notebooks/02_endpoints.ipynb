# %%
import requests

url = "http://127.0.0.1:8000/health"
response = requests.get(url)

print("Status code:", response.status_code)
print("Response:", response.json())
# Out:
# Status code: 200
# Response: {'status': 'ok'}

# %%
import requests
import json
import pandas as pd

url = "http://127.0.0.1:8000/predict"

# Load CSV and get last 30 rows (excluding 'Close') for sequence
df = pd.read_csv('../data/processed/df.csv')
sequence = df.drop(columns=['Close']).tail(30).values.tolist()  # 30 timesteps, input_size features
payload = {"sequence": sequence}

try:
    response = requests.post(url, json=payload, timeout=5)
    print(f"Status code: {response.status_code}")
    print("Response:", json.dumps(response.json(), indent=2))
except requests.exceptions.RequestException as e:
    print(f"Erro na requisição: {e}")
# Out:
# Status code: 422
# Response: {
#   "detail": [
#     {
#       "loc": [
#         "body",
#         "sequence",
#         0,
#         0
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
#     {
#       "loc": [
#         "body",
#         "sequence",
#         1,
#         0
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
#     {
#       "loc": [
#         "body",
#         "sequence",
#         2,
#         0
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
#     {
#       "loc": [
#         "body",
#         "sequence",
#         3,
#         0
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
#     {
#       "loc": [
#         "body",
#         "sequence",
#         4,
#         0
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
# ...

# %%
import requests
import json
import pandas as pd

url = "http://127.0.0.1:8000/predict"
df = pd.read_csv('../data/processed/df.csv')

# %%
sequence = df.drop(columns=['Date','Close']).tail(30).values.tolist()  # 30 linhas, sem 'Close'
sequence
# Out:
# [[14.6534423828125, 15.05042824499378, 14.55419591726718, 59052500.0],
#  [14.840255737304688, 15.132156911434588, 14.670952521822333, 66220400.0],
#  [14.77603816986084, 15.313136412865012, 14.75852481082121, 68042300.0],
#  [14.583381652832031, 14.93366326672971, 14.56003013911328, 48118600.0],
#  [14.12217903137207, 14.513326646897523, 14.069636731263085, 58605500.0],
#  [13.87114429473877, 14.437432186646372, 13.7777360056306, 58916700.0],
#  [13.625946044921877, 13.707678012239796, 13.310692262099248, 93708800.0],
#  [13.57924461364746, 13.73103337860228, 13.409941374981209, 66821000.0],
#  [13.725193977355955, 13.725193977355955, 13.345722656101968, 93502700.0],
#  [13.386588096618652, 13.806925388788216, 13.363235468074146, 57575200.0],
#  [13.660974502563477, 13.777735415706632, 13.4741579323461, 43391200.0],
#  [13.620108604431152, 13.78941181822385, 13.45080650415305, 46435600.0],
#  [13.310691833496094, 13.81860031829531, 13.188093886466854, 74711200.0],
# ...

# %%
payload = {"sequence": sequence}
payload
# Out:
# {'sequence': [[14.6534423828125,
#    15.05042824499378,
#    14.55419591726718,
#    59052500.0],
#   [14.840255737304688, 15.132156911434588, 14.670952521822333, 66220400.0],
#   [14.77603816986084, 15.313136412865012, 14.75852481082121, 68042300.0],
#   [14.583381652832031, 14.93366326672971, 14.56003013911328, 48118600.0],
#   [14.12217903137207, 14.513326646897523, 14.069636731263085, 58605500.0],
#   [13.87114429473877, 14.437432186646372, 13.7777360056306, 58916700.0],
#   [13.625946044921877, 13.707678012239796, 13.310692262099248, 93708800.0],
#   [13.57924461364746, 13.73103337860228, 13.409941374981209, 66821000.0],
#   [13.725193977355955, 13.725193977355955, 13.345722656101968, 93502700.0],
#   [13.386588096618652, 13.806925388788216, 13.363235468074146, 57575200.0],
#   [13.660974502563477, 13.777735415706632, 13.4741579323461, 43391200.0],
#   [13.620108604431152, 13.78941181822385, 13.45080650415305, 46435600.0],
# ...

# %%
try:
    response = requests.post(url, json=payload, timeout=5)
    print(f"Status code: {response.status_code}")
    print("Response:", json.dumps(response.json(), indent=2))
except requests.exceptions.RequestException as e:
    print(f"Erro na requisição: {e}")
# Out:
# Status code: 422
# Response: {
#   "detail": [
#     {
#       "loc": [
#         "body",
#         "sequence",
#         0
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
#     {
#       "loc": [
#         "body",
#         "sequence",
#         1
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
#     {
#       "loc": [
#         "body",
#         "sequence",
#         2
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
#     {
#       "loc": [
#         "body",
#         "sequence",
#         3
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
#     {
#       "loc": [
#         "body",
#         "sequence",
#         4
#       ],
#       "msg": "value is not a valid float",
#       "type": "type_error.float"
#     },
#     {
#       "loc": [
#         "body",
#         "sequence",
# ...

# %%
import requests

url = "http://127.0.0.1:8000/metrics"
response = requests.get(url)

print("Status code:", response.status_code)
print("Trecho das métricas:\n")
print(response.text[:500])  # imprime só o início
# Out:
# Status code: 200
# Trecho das métricas:
#
# # HELP python_gc_objects_collected_total Objects collected during gc
# # TYPE python_gc_objects_collected_total counter
# python_gc_objects_collected_total{generation="0"} 6398.0
# python_gc_objects_collected_total{generation="1"} 787.0
# python_gc_objects_collected_total{generation="2"} 70.0
# # HELP python_gc_objects_uncollectable_total Uncollectable objects found during GC
# # TYPE python_gc_objects_uncollectable_total counter
# python_gc_objects_uncollectable_total{generation="0"} 0.0
# python_gc_objects_un

# %%
import requests

url = "http://127.0.0.1:8000/reload"
response = requests.post(url)

print("Status code:", response.status_code)
print("Response:", response.json())
# Out:
# Status code: 200
# Response: {'reloading': True}
